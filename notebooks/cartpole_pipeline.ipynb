# %%
# %load_ext autoreload
# %autoreload 2

import featuregraph_research as fg
import pandas as pd

# %%
cartpole = fg.datasets.cartpole()

# %%
cartpole
# Out:
#       episode  step  time  episode_start  cart_position  cart_velocity  \
# 0           0     0  0.00           True      -0.046926      -0.033154
# 1           0     1  0.02          False      -0.047589      -0.227975
# 2           0     2  0.04          False      -0.052148      -0.422799
# 3           0     3  0.06          False      -0.060604      -0.617714
# 4           0     4  0.08          False      -0.072959      -0.812795
# ...       ...   ...   ...            ...            ...            ...
# 4995        9   495  9.90          False       0.241014       0.235558
# 4996        9   496  9.92          False       0.245725       0.041233
# 4997        9   497  9.94          False       0.246550      -0.153059
# 4998        9   498  9.96          False       0.243488      -0.347414
# 4999        9   499  9.98          False       0.236540      -0.541920
#
#       pole_angle  pole_angular_velocity  action  control_score  reward  \
# ...

# %%
fg.plot(cartpole[500:600], [
                            ['cart_position'],
                            ['pole_angle'], 
                            ['pole_angular_velocity'],
                            ['action']
                            ])
# Out:
# (<Figure size 1600x880 with 4 Axes>,
#  array([<Axes: ylabel='cart_position'>, <Axes: ylabel='pole_angle'>,
#         <Axes: ylabel='pole_angular_velocity'>,
#         <Axes: xlabel='Time', ylabel='action'>], dtype=object))
